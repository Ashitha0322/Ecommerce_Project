# %% [markdown]
# ## <mark> Ecommerce Data Analysis  Project Using Pandas <mark>

# %% [markdown]
# ### PART 1: DATA LOADING & INITIAL EXPLORATION

# %% [markdown]
# **Import libraries**

# %%
import pandas as pd

# %% [markdown]
# #### TASK 1.1 - Load the Data Set

# %% [markdown]
# **Load the dataset**

# %%
Ecom_df=pd.read_csv("C:\\Users\\P.ASHITHA\\Downloads\\ecommerce_raw_data.csv",delimiter=',')

# %%
Ecom_df.head()
# Out:
#      order_id customer_id           order_date        delivery_date  \
# 0  ORD0499319   CUST81768  2024-11-06 19:04:00  2024-11-14 19:04:00
# 1  ORD0380643   CUST30450  2024-09-09 22:22:00  2024-09-15 22:22:00
# 2  ORD0371106   CUST82803  2024-08-23 07:22:00  2024-08-31 07:22:00
# 3  ORD0150743   CUST82106  2024-07-03 19:52:00  2024-07-13 19:52:00
# 4  ORD0619524   CUST71248  2024-02-11 11:19:00  2024-02-18 11:19:00
#
#        product_name        category  quantity    price  total_amount  \
# 0          vacuum    Home & Kitchen         4  2191.51       8766.04
# 1    Organic Snacks         Grocery         3   704.72       2114.16
# 2          LEGO Set            Toys         2   694.01       1388.02
# 3    coffee maker    Home & Kitchen         4  7376.81      29507.24
# 4             Dress        Clothing         4  2774.72      11098.88
#
#      payment_method       city order_status
# 0  Cash on Delivery       Pune    Delivered
# 1        Debit Card    Kolkata    Delivered
# ...

# %%
Ecom_df.info()
#Display basic info about the dataset.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005000 entries, 0 to 1004999
# Data columns (total 12 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   order_id        1005000 non-null  object
#  1   customer_id     955122 non-null   object
#  2   order_date      1005000 non-null  object
#  3   delivery_date   924622 non-null   object
#  4   product_name    1005000 non-null  object
#  5   category        1005000 non-null  object
#  6   quantity        1005000 non-null  int64
#  7   price           1005000 non-null  float64
#  8   total_amount    1005000 non-null  float64
#  9   payment_method  984624 non-null   object
#  10  city            974718 non-null   object
#  11  order_status    1005000 non-null  object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 92.0+ MB

# %%
Ecom_df.isnull().sum()
# Out:
# order_id              0
# customer_id       49878
# order_date            0
# delivery_date     80378
# product_name          0
# category              0
# quantity              0
# price                 0
# total_amount          0
# payment_method    20376
# city              30282
# order_status          0
# dtype: int64

# %% [markdown]
# ### TASK 1.2: Understand the Data Structure

# %%
#Display the first 10 rows 
Ecom_df.head(10)
# Out:
#      order_id customer_id           order_date        delivery_date  \
# 0  ORD0499319   CUST81768  2024-11-06 19:04:00  2024-11-14 19:04:00
# 1  ORD0380643   CUST30450  2024-09-09 22:22:00  2024-09-15 22:22:00
# 2  ORD0371106   CUST82803  2024-08-23 07:22:00  2024-08-31 07:22:00
# 3  ORD0150743   CUST82106  2024-07-03 19:52:00  2024-07-13 19:52:00
# 4  ORD0619524   CUST71248  2024-02-11 11:19:00  2024-02-18 11:19:00
# 5  ORD0021905   CUST32249  2024-03-03 20:27:00  2024-03-09 20:27:00
# 6  ORD0774363   CUST76479  2023-05-13 23:40:00                  NaN
# 7  ORD0147626   CUST74013  2024-12-21 11:51:00  2024-12-31 11:51:00
# 8  ORD0831928   CUST55081  2023-11-11 02:44:00  2023-11-18 02:44:00
# 9  ORD0810242   CUST99389  2023-10-08 19:58:00  2023-10-12 19:58:00
#
#        product_name        category  quantity     price  total_amount  \
# 0          vacuum    Home & Kitchen         4   2191.51       8766.04
# 1    Organic Snacks         Grocery         3    704.72       2114.16
# ...

# %%
#last 5 rows
Ecom_df.tail(5)
# Out:
#            order_id customer_id           order_date        delivery_date  \
# 1004995  ORD0259179   CUST55662  2024-12-01 02:05:00  2024-12-10 02:05:00
# 1004996  ORD0365839   CUST87001  2024-09-16 21:13:00  2024-09-24 21:13:00
# 1004997  ORD0131933   CUST10790  2023-06-24 17:09:00  2023-07-03 17:09:00
# 1004998  ORD0671156   CUST86849  2024-09-22 02:03:00  2024-09-30 02:03:00
# 1004999  ORD0121959   CUST61990  2023-09-16 21:59:00  2023-09-25 21:59:00
#
#          product_name        category  quantity     price  total_amount  \
# 1004995  Cookware Set  Home & Kitchen         4  14436.05      57744.20
# 1004996      Cookbook           Books         3    630.14       1890.42
# 1004997    Board Game            Toys         1   2383.59       2383.59
# 1004998        Cereal         Grocery         2    121.20        242.40
# 1004999    Makeup Kit          Beauty         3   1865.85       5597.55
#
#            payment_method       city order_status
# ...

# %%
#Show dataset shape (rows, columns)
Ecom_df.shape
# Out:
# (1005000, 12)

# %%
Ecom_df.size
# Out:
# 12060000

# %%
#list of all columns
Ecom_df.columns
# Out:
# Index(['order_id', 'customer_id', 'order_date', 'delivery_date',
#        'product_name', 'category', 'quantity', 'price', 'total_amount',
#        'payment_method', 'city', 'order_status'],
#       dtype='object')

# %%
Ecom_df.dtypes
# Out:
# order_id           object
# customer_id        object
# order_date         object
# delivery_date      object
# product_name       object
# category           object
# quantity            int64
# price             float64
# total_amount      float64
# payment_method     object
# city               object
# order_status       object
# dtype: object

# %% [markdown]
# ### TASK 1.3: Basic Statistics

# %%
Ecom_df.describe().round(2)
#providing statistical info
# Out:
#          quantity       price  total_amount
# count  1005000.00  1005000.00    1005000.00
# mean         2.88     7263.50      20897.12
# std          1.65    15579.85      53078.99
# min         -5.00        0.00    -399985.85
# 25%          2.00      652.78       1537.32
# 50%          3.00     1493.15       3739.84
# 75%          4.00     3972.47      11204.24
# max          5.00    79999.59     399997.95

# %%
#Count unique values per column
Unique_counts=Ecom_df.nunique()
print(Unique_counts)
# Out:
# order_id          1000000
# customer_id         89998
# order_date         645031
# delivery_date      613697
# product_name           84
# category                8
# quantity               10
# price              506339
# total_amount       673257
# payment_method          5
# city                   10
# order_status            3
# dtype: int64

# %%
#Memory consumption details.
Ecom_df.memory_usage()
# Out:
# Index                 132
# order_id          8040000
# customer_id       8040000
# order_date        8040000
# delivery_date     8040000
# product_name      8040000
# category          8040000
# quantity          8040000
# price             8040000
# total_amount      8040000
# payment_method    8040000
# city              8040000
# order_status      8040000
# dtype: int64

# %% [markdown]
# ### PART 2: DATA QUALITY ASSESSMENT

# %% [markdown]
# ### TASK 2.1: Missing Values Analysis

# %%
#Identify columns with missing or null values
Ecom_df.isnull()
# Out:
#          order_id  customer_id  order_date  delivery_date  product_name  \
# 0           False        False       False          False         False
# 1           False        False       False          False         False
# 2           False        False       False          False         False
# 3           False        False       False          False         False
# 4           False        False       False          False         False
# ...           ...          ...         ...            ...           ...
# 1004995     False        False       False          False         False
# 1004996     False        False       False          False         False
# 1004997     False        False       False          False         False
# 1004998     False        False       False          False         False
# 1004999     False        False       False          False         False
#
#          category  quantity  price  total_amount  payment_method   city  \
# ...

# %%
#counting missing values per column
Ecom_df.isnull().sum()
# Out:
# order_id              0
# customer_id       49878
# order_date            0
# delivery_date     80378
# product_name          0
# category              0
# quantity              0
# price                 0
# total_amount          0
# payment_method    20376
# city              30282
# order_status          0
# dtype: int64

# %%
#Calculate the percentage of missing data per column
missing_per=Ecom_df.isnull().sum()/len(Ecom_df)*100
print(missing_per)
# Out:
# order_id          0.000000
# customer_id       4.962985
# order_date        0.000000
# delivery_date     7.997811
# product_name      0.000000
# category          0.000000
# quantity          0.000000
# price             0.000000
# total_amount      0.000000
# payment_method    2.027463
# city              3.013134
# order_status      0.000000
# dtype: float64

# %%
len(Ecom_df),Ecom_df.shape
# Out:
# (1005000, (1005000, 12))

# %% [markdown]
# ### TASK 2.2: Check for Duplicates

# %%
#Identify  duplicate rows
mask=Ecom_df.duplicated()
Ecom_df[mask]
# Out:
#            order_id customer_id           order_date        delivery_date  \
# 8388     ORD0147821   CUST12847  2023-02-11 18:24:00  2023-02-20 18:24:00
# 10336    ORD0916877   CUST93574  2024-08-21 15:11:00  2024-08-29 15:11:00
# 11331    ORD0765768   CUST30186  2024-11-17 05:25:00  2024-11-25 05:25:00
# 28455    ORD0007139   CUST37894  2024-10-11 04:03:00                  NaN
# 32215    ORD0622638   CUST95702  2023-08-10 11:02:00                  NaN
# ...             ...         ...                  ...                  ...
# 1004427  ORD0971526   CUST47642  2024-01-10 12:30:00  2024-01-15 12:30:00
# 1004565  ORD0116382   CUST21627  2023-03-19 09:42:00  2023-03-28 09:42:00
# 1004782  ORD0043586   CUST70657  2023-01-11 19:20:00  2023-01-15 19:20:00
# 1004817  ORD0897422   CUST56032  2024-11-14 22:17:00  2024-11-19 22:17:00
# 1004832  ORD0967901   CUST93220  2023-03-07 00:41:00  2023-03-11 00:41:00
#
#           product_name     category  quantity     price  total_amount  \
# ...

# %%
#count of duplicate rows
[Ecom_df.duplicated().sum()]
# Out:
# [np.int64(5000)]

# %%
#duplicate order_id's
Ecom_df['order_id'].duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1004995    False
# 1004996    False
# 1004997    False
# 1004998    False
# 1004999    False
# Name: order_id, Length: 1005000, dtype: bool

# %%
mask=Ecom_df.duplicated()
Ecom_df[mask].sort_values(by=['order_id'])
# Out:
#           order_id customer_id           order_date        delivery_date  \
# 980722  ORD0000616   CUST49460  2023-09-25 01:19:00  2023-10-04 01:19:00
# 707984  ORD0000632   CUST17784  2023-04-01 18:32:00  2023-04-05 18:32:00
# 574644  ORD0000680   CUST46403  2023-12-31 20:58:00  2024-01-09 20:58:00
# 755244  ORD0001545         NaN  2024-07-17 05:23:00  2024-07-26 05:23:00
# 790386  ORD0002081   CUST55903  2023-08-24 20:02:00                  NaN
# ...            ...         ...                  ...                  ...
# 994406  ORD0999508   CUST48530  2023-05-12 05:47:00  2023-05-18 05:47:00
# 675508  ORD0999607   CUST37367  2023-07-08 15:07:00  2023-07-15 15:07:00
# 719145  ORD0999646   CUST90644  2024-11-03 03:30:00  2024-11-08 03:30:00
# 743804  ORD0999797   CUST75449  2023-01-10 11:58:00  2023-01-19 11:58:00
# 545650  ORD0999850   CUST15237  2023-07-18 23:38:00  2023-07-24 23:38:00
#
#         product_name        category  quantity     price  total_amount  \
# ...

# %%
mask=Ecom_df['order_id']=='ORD0000616'
Ecom_df[mask]
# Out:
#           order_id customer_id           order_date        delivery_date  \
# 311000  ORD0000616   CUST49460  2023-09-25 01:19:00  2023-10-04 01:19:00
# 980722  ORD0000616   CUST49460  2023-09-25 01:19:00  2023-10-04 01:19:00
#
#         product_name        category  quantity    price  total_amount  \
# 311000  Coffee Maker  Home & Kitchen         4  4500.29      18001.16
# 980722  Coffee Maker  Home & Kitchen         4  4500.29      18001.16
#
#        payment_method     city order_status
# 311000    Net Banking  Chennai    Delivered
# 980722    Net Banking  Chennai    Delivered

# %% [markdown]
# ### TASK 2.3: Data Type Issues

# %%
#Check data types of all columns
Ecom_df.dtypes
# Out:
# order_id           object
# customer_id        object
# order_date         object
# delivery_date      object
# product_name       object
# category           object
# quantity            int64
# price             float64
# total_amount      float64
# payment_method     object
# city               object
# order_status       object
# dtype: object

# %%
Ecom_df.head(2)
# Out:
#      order_id customer_id           order_date        delivery_date  \
# 0  ORD0499319   CUST81768  2024-11-06 19:04:00  2024-11-14 19:04:00
# 1  ORD0380643   CUST30450  2024-09-09 22:22:00  2024-09-15 22:22:00
#
#      product_name        category  quantity    price  total_amount  \
# 0        vacuum    Home & Kitchen         4  2191.51       8766.04
# 1  Organic Snacks         Grocery         3   704.72       2114.16
#
#      payment_method     city order_status
# 0  Cash on Delivery     Pune    Delivered
# 1        Debit Card  Kolkata    Delivered

# %%
#converting order_date, delivery_date into datetime 
#Ecom_df['order_date']=pd.to_datetime(Ecom_df['order_date'])
#Ecom_df['delivery_date']=pd.to_datetime(Ecom_df['delivery_date'])

# %% [markdown]
# ## PART 3: DATA CLEANING

# %% [markdown]
# ### TASK 3.1: Remove Duplicate Orders

# %%
#Drop duplicate records based on order_id
Ecom_df.drop_duplicates(subset=['order_id'],inplace=True)

# %%
Ecom_df.shape
# Out:
# (1000000, 12)

# %%
Ecom_df.head(5)
# Out:
#      order_id customer_id           order_date        delivery_date  \
# 0  ORD0499319   CUST81768  2024-11-06 19:04:00  2024-11-14 19:04:00
# 1  ORD0380643   CUST30450  2024-09-09 22:22:00  2024-09-15 22:22:00
# 2  ORD0371106   CUST82803  2024-08-23 07:22:00  2024-08-31 07:22:00
# 3  ORD0150743   CUST82106  2024-07-03 19:52:00  2024-07-13 19:52:00
# 4  ORD0619524   CUST71248  2024-02-11 11:19:00  2024-02-18 11:19:00
#
#        product_name        category  quantity    price  total_amount  \
# 0          vacuum    Home & Kitchen         4  2191.51       8766.04
# 1    Organic Snacks         Grocery         3   704.72       2114.16
# 2          LEGO Set            Toys         2   694.01       1388.02
# 3    coffee maker    Home & Kitchen         4  7376.81      29507.24
# 4             Dress        Clothing         4  2774.72      11098.88
#
#      payment_method       city order_status
# 0  Cash on Delivery       Pune    Delivered
# 1        Debit Card    Kolkata    Delivered
# ...

# %%
#checking for any kind of duplicates
mask=Ecom_df['order_id']=='ORD0000632'
Ecom_df[mask]
# Out:
#           order_id customer_id           order_date        delivery_date  \
# 628686  ORD0000632   CUST17784  2023-04-01 18:32:00  2023-04-05 18:32:00
#
#        product_name     category  quantity     price  total_amount  \
# 628686   Headphones  Electronics         2  36605.43      73210.86
#
#        payment_method    city order_status
# 628686            UPI  Jaipur    Delivered

# %% [markdown]
# ### TASK 3.2: Handle Missing Values

# %%
Ecom_df.isnull().sum()
# Out:
# order_id              0
# customer_id       49624
# order_date            0
# delivery_date     79994
# product_name          0
# category              0
# quantity              0
# price                 0
# total_amount          0
# payment_method    20287
# city              30115
# order_status          0
# dtype: int64

# %%
# checking the misssing values percentage in each column
(Ecom_df.isnull().sum()/Ecom_df.shape[0]) * 100
# Out:
# order_id          0.0000
# customer_id       4.9624
# order_date        0.0000
# delivery_date     7.9994
# product_name      0.0000
# category          0.0000
# quantity          0.0000
# price             0.0000
# total_amount      0.0000
# payment_method    2.0287
# city              3.0115
# order_status      0.0000
# dtype: float64

# %% [markdown]
# + my standard: if missing values percentage is less than 5 , I will drop the column else no

# %%
for col in Ecom_df.columns:
    missing_per=(Ecom_df[col].isnull().sum()/Ecom_df.shape[0]) * 100
    if missing_per <5:
        Ecom_df.dropna(subset=[col])
    else:
        print(f" the missing percentage is {missing_per}, so we should not drop the column.")
# Out:
#  the missing percentage is 7.9994, so we should not drop the column.

# %%
#dropping missing values permanently
Ecom_df.dropna(subset=['customer_id','payment_method','city'],inplace=True)

# %%
Ecom_df.shape
# Out:
# (903076, 12)

# %% [markdown]
# ### TASK 3.3: Fix Data Quality Issues

# %%
#Correct incorrect data types (e.g., dates, prices).
#converting order_id into datetime 
Ecom_df['order_date']=pd.to_datetime(Ecom_df['order_date'])
Ecom_df['delivery_date']=pd.to_datetime(Ecom_df['delivery_date'])

# %%
#Standardize categorical entries
mask=['category','payment_method','city','order_status']

for col in mask:
    print(f"Unique values in '{col}':")
    print(Ecom_df[col].unique())
# Out:
# Unique values in 'category':
# ['Home & Kitchen' 'Grocery' 'Toys' 'Clothing' 'Beauty' 'Electronics'
#  'Sports' 'Books']
# Unique values in 'payment_method':
# ['Cash on Delivery' 'Debit Card' 'UPI' 'Credit Card' 'Net Banking']
# Unique values in 'city':
# ['Pune' 'Kolkata' 'Bangalore' 'Mumbai' 'Delhi' 'Hyderabad' 'Chennai'
#  'Jaipur' 'Ahmedabad' 'Surat']
# Unique values in 'order_status':
# ['Delivered' 'Returned' 'Pending']

# %% [markdown]
# ### TASK 3.4: Clean Text Data

# %%
Ecom_df.head()
# Out:
#      order_id customer_id          order_date       delivery_date  \
# 0  ORD0499319   CUST81768 2024-11-06 19:04:00 2024-11-14 19:04:00
# 1  ORD0380643   CUST30450 2024-09-09 22:22:00 2024-09-15 22:22:00
# 2  ORD0371106   CUST82803 2024-08-23 07:22:00 2024-08-31 07:22:00
# 3  ORD0150743   CUST82106 2024-07-03 19:52:00 2024-07-13 19:52:00
# 4  ORD0619524   CUST71248 2024-02-11 11:19:00 2024-02-18 11:19:00
#
#        product_name        category  quantity    price  total_amount  \
# 0          vacuum    Home & Kitchen         4  2191.51       8766.04
# 1    Organic Snacks         Grocery         3   704.72       2114.16
# 2          LEGO Set            Toys         2   694.01       1388.02
# 3    coffee maker    Home & Kitchen         4  7376.81      29507.24
# 4             Dress        Clothing         4  2774.72      11098.88
#
#      payment_method       city order_status
# 0  Cash on Delivery       Pune    Delivered
# 1        Debit Card    Kolkata    Delivered
# ...

# %%
#Fix inconsistent names
Ecom_df['product_name']=Ecom_df['product_name'].str.title()

# %%
#using apply function for categories
Ecom_df[['product_name','category','payment_method','city','order_status']]=Ecom_df[['product_name','category','payment_method','city','order_status']].apply(lambda x:x.str.title())

# %% [markdown]
# ### TASK 3.5: Recalculate Total Amount

# %%
#Recalculate total_amount = quantity × price
Ecom_df['total_amount']=Ecom_df['quantity']*Ecom_df['price']

# %%
Ecom_df['total_amount']
# Out:
# 0           8766.04
# 1           2114.16
# 2           1388.02
# 3          29507.24
# 4          11098.88
#              ...
# 1004995    57744.20
# 1004996     1890.42
# 1004997     2383.59
# 1004998      242.40
# 1004999     5597.55
# Name: total_amount, Length: 903076, dtype: float64

# %% [markdown]
# ### TASK 3.6: Reset Index

# %%
#Reset index to reflect the cleaned data
Ecom_df.reset_index()
# Out:
#           index    order_id customer_id          order_date  \
# 0             0  ORD0499319   CUST81768 2024-11-06 19:04:00
# 1             1  ORD0380643   CUST30450 2024-09-09 22:22:00
# 2             2  ORD0371106   CUST82803 2024-08-23 07:22:00
# 3             3  ORD0150743   CUST82106 2024-07-03 19:52:00
# 4             4  ORD0619524   CUST71248 2024-02-11 11:19:00
# ...         ...         ...         ...                 ...
# 903071  1004995  ORD0259179   CUST55662 2024-12-01 02:05:00
# 903072  1004996  ORD0365839   CUST87001 2024-09-16 21:13:00
# 903073  1004997  ORD0131933   CUST10790 2023-06-24 17:09:00
# 903074  1004998  ORD0671156   CUST86849 2024-09-22 02:03:00
# 903075  1004999  ORD0121959   CUST61990 2023-09-16 21:59:00
#
#              delivery_date      product_name        category  quantity  \
# 0      2024-11-14 19:04:00          Vacuum    Home & Kitchen         4
# 1      2024-09-15 22:22:00    Organic Snacks         Grocery         3
# ...

# %% [markdown]
# ## PART 4: FEATURE ENGINEERING

# %% [markdown]
# ### TASK 4.1: Extract Date Components

# %%
#converting order_id into datetime 
Ecom_df['order_date']=pd.to_datetime(Ecom_df['order_date'])
Ecom_df['delivery_date']=pd.to_datetime(Ecom_df['delivery_date'])

# %%
Ecom_df.dtypes
# Out:
# order_id                    object
# customer_id                 object
# order_date          datetime64[ns]
# delivery_date       datetime64[ns]
# product_name                object
# category                    object
# quantity                     int64
# price                      float64
# total_amount               float64
# payment_method              object
# city                        object
# order_status                object
# order_year                   int32
# order_month                  int32
# order_day                    int32
# order_weekday               object
# delivery_days                int64
# price_category              object
# customer_segment            object
# dtype: object

# %%
Ecom_df['order_year']=Ecom_df['order_date'].dt.year
Ecom_df['order_month']=Ecom_df['order_date'].dt.month
Ecom_df['order_day']=Ecom_df['order_date'].dt.day
Ecom_df['order_weekday']=Ecom_df['order_date'].dt.day_name()

# %%
Ecom_df.columns
# Out:
# Index(['order_id', 'customer_id', 'order_date', 'delivery_date',
#        'product_name', 'category', 'quantity', 'price', 'total_amount',
#        'payment_method', 'city', 'order_status', 'order_year', 'order_month',
#        'order_day', 'order_weekday', 'delivery_days', 'price_category',
#        'customer_segment'],
#       dtype='object')

# %% [markdown]
# ### TASK 4.2: Calculate Delivery Time

# %%
#Calculate delivery_days = delivery_date - order_date.
Ecom_df.head()
# Out:
#      order_id customer_id          order_date       delivery_date  \
# 0  ORD0499319   CUST81768 2024-11-06 19:04:00 2024-11-14 19:04:00
# 1  ORD0380643   CUST30450 2024-09-09 22:22:00 2024-09-15 22:22:00
# 2  ORD0371106   CUST82803 2024-08-23 07:22:00 2024-08-31 07:22:00
# 3  ORD0150743   CUST82106 2024-07-03 19:52:00 2024-07-13 19:52:00
# 4  ORD0619524   CUST71248 2024-02-11 11:19:00 2024-02-18 11:19:00
#
#        product_name        category  quantity    price  total_amount  \
# 0          Vacuum    Home & Kitchen         4  2191.51       8766.04
# 1    Organic Snacks         Grocery         3   704.72       2114.16
# 2          Lego Set            Toys         2   694.01       1388.02
# 3    Coffee Maker    Home & Kitchen         4  7376.81      29507.24
# 4             Dress        Clothing         4  2774.72      11098.88
#
#      payment_method       city order_status  order_year  order_month  \
# 0  Cash On Delivery       Pune    Delivered        2024           11
# ...

# %%
Ecom_df['delivery_days']=Ecom_df['delivery_date'].dt.day-Ecom_df['order_day']

# %%
Ecom_df['delivery_days'] = Ecom_df['delivery_days'].fillna(0).astype(int)
# the col may contain missing values so filling with 0 and converting into integer

# %%
Ecom_df['delivery_days'] = Ecom_df['delivery_days'].abs()

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
median_date = Ecom_df['delivery_date'].median()
Ecom_df['delivery_date'].fillna(median_date, inplace=True)

# %%
Ecom_df.head()
# Out:
#      order_id customer_id          order_date       delivery_date  \
# 0  ORD0499319   CUST81768 2024-11-06 19:04:00 2024-11-14 19:04:00
# 1  ORD0380643   CUST30450 2024-09-09 22:22:00 2024-09-15 22:22:00
# 2  ORD0371106   CUST82803 2024-08-23 07:22:00 2024-08-31 07:22:00
# 3  ORD0150743   CUST82106 2024-07-03 19:52:00 2024-07-13 19:52:00
# 4  ORD0619524   CUST71248 2024-02-11 11:19:00 2024-02-18 11:19:00
#
#        product_name        category  quantity    price  total_amount  \
# 0          Vacuum    Home & Kitchen         4  2191.51       8766.04
# 1    Organic Snacks         Grocery         3   704.72       2114.16
# 2          Lego Set            Toys         2   694.01       1388.02
# 3    Coffee Maker    Home & Kitchen         4  7376.81      29507.24
# 4             Dress        Clothing         4  2774.72      11098.88
#
#      payment_method       city order_status  order_year  order_month  \
# 0  Cash On Delivery       Pune    Delivered        2024           11
# ...

# %% [markdown]
# ### TASK 4.3: Create Price Categories

# %%
Ecom_df['price'].describe()
# Out:
# count    903076.000000
# mean       7270.527995
# std       15595.217496
# min           0.000000
# 25%         652.760000
# 50%        1492.940000
# 75%        3974.967500
# max       79999.590000
# Name: price, dtype: float64

# %%
import numpy as np
help(np.where)
# Out:
# Help on _ArrayFunctionDispatcher in module numpy:
#
# where(...)
#     where(condition, [x, y], /)
#
#     Return elements chosen from `x` or `y` depending on `condition`.
#
#     .. note::
#         When only `condition` is provided, this function is a shorthand for
#         ``np.asarray(condition).nonzero()``. Using `nonzero` directly should be
#         preferred, as it behaves correctly for subclasses. The rest of this
#         documentation covers only the case where all three arguments are
#         provided.
#
#     Parameters
#     ----------
#     condition : array_like, bool
#         Where True, yield `x`, otherwise yield `y`.
#     x, y : array_like
#         Values from which to choose. `x`, `y` and `condition` need to be
#         broadcastable to some shape.
#
#     Returns
#     -------
#     out : ndarray
#         An array with elements from `x` where `condition` is True, and elements
#         from `y` elsewhere.
#
#     See Also
#     --------
#     choose
# ...

# %%
import numpy as np

Ecom_df['price_category'] = np.where(
    Ecom_df['price'] <= 30000, 'Low',
    np.where((Ecom_df['price'] > 30000) & (Ecom_df['price'] <= 50000), 'Medium','High')
)

# %%
Ecom_df.head()
# Out:
#      order_id customer_id          order_date       delivery_date  \
# 0  ORD0499319   CUST81768 2024-11-06 19:04:00 2024-11-14 19:04:00
# 1  ORD0380643   CUST30450 2024-09-09 22:22:00 2024-09-15 22:22:00
# 2  ORD0371106   CUST82803 2024-08-23 07:22:00 2024-08-31 07:22:00
# 3  ORD0150743   CUST82106 2024-07-03 19:52:00 2024-07-13 19:52:00
# 4  ORD0619524   CUST71248 2024-02-11 11:19:00 2024-02-18 11:19:00
#
#        product_name        category  quantity    price  total_amount  \
# 0          Vacuum    Home & Kitchen         4  2191.51       8766.04
# 1    Organic Snacks         Grocery         3   704.72       2114.16
# 2          Lego Set            Toys         2   694.01       1388.02
# 3    Coffee Maker    Home & Kitchen         4  7376.81      29507.24
# 4             Dress        Clothing         4  2774.72      11098.88
#
#      payment_method       city order_status  order_year  order_month  \
# 0  Cash On Delivery       Pune    Delivered        2024           11
# ...

# %% [markdown]
# ### TASK 4.4: Create Customer Segments

# %%
Ecom_df.groupby('customer_id')['total_amount'].sum().reset_index()
# Out:
#       customer_id  total_amount
# 0       CUST10000     359016.43
# 1       CUST10001     286579.48
# 2       CUST10002     331355.78
# 3       CUST10003      33450.64
# 4       CUST10004      18786.35
# ...           ...           ...
# 89990   CUST99995     116263.96
# 89991   CUST99996     241827.13
# 89992   CUST99997     258667.32
# 89993   CUST99998     144023.94
# 89994   CUST99999     214673.67
#
# [89995 rows x 2 columns]

# %%
Ecom_df['total_amount']=Ecom_df['total_amount'].abs()
Ecom_df['total_amount'].max()
# Out:
# np.float64(399997.94999999995)

# %%
import numpy as np

Ecom_df['customer_segment'] = np.where(
    Ecom_df['total_amount'] <= 100000, 'Bronze',
    np.where((Ecom_df['total_amount'] >100000) & (Ecom_df['total_amount'] <=250000), 'Silver', 'Gold')
)

# %%
Ecom_df.head(2)
# Out:
#      order_id customer_id          order_date       delivery_date  \
# 0  ORD0499319   CUST81768 2024-11-06 19:04:00 2024-11-14 19:04:00
# 1  ORD0380643   CUST30450 2024-09-09 22:22:00 2024-09-15 22:22:00
#
#      product_name        category  quantity    price  total_amount  \
# 0        Vacuum    Home & Kitchen         4  2191.51       8766.04
# 1  Organic Snacks         Grocery         3   704.72       2114.16
#
#      payment_method     city order_status  order_year  order_month  order_day  \
# 0  Cash On Delivery     Pune    Delivered        2024           11          6
# 1        Debit Card  Kolkata    Delivered        2024            9          9
#
#   order_weekday  delivery_days price_category customer_segment  \
# 0     Wednesday              8            Low           Bronze
# 1        Monday              6            Low           Bronze
#
#    product_revenue_percent
# 0                 0.032350
# 1                 0.006086

# %% [markdown]
# ##  PART 5: DATA EXPLORATION & FILTERING

# %% [markdown]
# ### TASK 5.1: Filter Data by Conditions

# %%
Ecom_df[(Ecom_df['order_status']=='Delivered') & (Ecom_df['city']=='Bangalore')]
# Out:
#            order_id customer_id          order_date       delivery_date  \
# 2        ORD0371106   CUST82803 2024-08-23 07:22:00 2024-08-31 07:22:00
# 3        ORD0150743   CUST82106 2024-07-03 19:52:00 2024-07-13 19:52:00
# 26       ORD0308796   CUST79932 2024-08-30 22:46:00 2024-09-02 22:46:00
# 28       ORD0079083   CUST64620 2023-09-18 17:28:00 2023-09-24 17:28:00
# 46       ORD0037264   CUST59895 2024-07-29 19:56:00 2024-08-07 19:56:00
# ...             ...         ...                 ...                 ...
# 1004942  ORD0902649   CUST99330 2023-08-26 18:53:00 2023-09-05 18:53:00
# 1004953  ORD0648144   CUST89986 2023-03-23 12:21:00 2023-04-01 12:21:00
# 1004966  ORD0347450   CUST88767 2024-01-02 04:47:00 2024-01-06 04:47:00
# 1004977  ORD0787202   CUST31332 2023-08-11 07:09:00 2023-08-20 07:09:00
# 1004993  ORD0110269   CUST52481 2024-07-16 02:04:00 2024-07-20 02:04:00
#
#              product_name        category  quantity     price  total_amount  \
# ...

# %%
Ecom_df['delivery_days']>6
# Out:
# 0           True
# 1          False
# 2           True
# 3           True
# 4           True
#            ...
# 1004995     True
# 1004996     True
# 1004997     True
# 1004998     True
# 1004999     True
# Name: delivery_days, Length: 903076, dtype: bool

# %%
Ecom_df['payment_method']=='Cash on Delivery'
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1004995    False
# 1004996    False
# 1004997    False
# 1004998    False
# 1004999    False
# Name: payment_method, Length: 903076, dtype: bool

# %%
Ecom_df['total_amount']>50000
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1004995     True
# 1004996    False
# 1004997    False
# 1004998    False
# 1004999    False
# Name: total_amount, Length: 903076, dtype: bool

# %% [markdown]
# ### TASK 5.2: Select Specific Columns

# %%
#Select relevant columns for inspection
Ecom_df.head(2)
# Out:
#      order_id customer_id          order_date       delivery_date  \
# 0  ORD0499319   CUST81768 2024-11-06 19:04:00 2024-11-14 19:04:00
# 1  ORD0380643   CUST30450 2024-09-09 22:22:00 2024-09-15 22:22:00
#
#      product_name        category  quantity    price  total_amount  \
# 0        Vacuum    Home & Kitchen         4  2191.51       8766.04
# 1  Organic Snacks         Grocery         3   704.72       2114.16
#
#      payment_method     city order_status  order_year  order_month  order_day  \
# 0  Cash On Delivery     Pune    Delivered        2024           11          6
# 1        Debit Card  Kolkata    Delivered        2024            9          9
#
#   order_weekday  delivery_days price_category customer_segment  \
# 0     Wednesday              8            Low           Bronze
# 1        Monday              6            Low           Bronze
#
#    product_revenue_percent
# 0                 0.032350
# 1                 0.006086

# %%
cols_list=['order_id','customer_id','product_name','total_amount','payment_method','city','order_status']
Ecom_df[cols_list]
# Out:
#            order_id customer_id      product_name  total_amount  \
# 0        ORD0499319   CUST81768          Vacuum         8766.04
# 1        ORD0380643   CUST30450    Organic Snacks       2114.16
# 2        ORD0371106   CUST82803          Lego Set       1388.02
# 3        ORD0150743   CUST82106    Coffee Maker        29507.24
# 4        ORD0619524   CUST71248             Dress      11098.88
# ...             ...         ...               ...           ...
# 1004995  ORD0259179   CUST55662      Cookware Set      57744.20
# 1004996  ORD0365839   CUST87001          Cookbook       1890.42
# 1004997  ORD0131933   CUST10790        Board Game       2383.59
# 1004998  ORD0671156   CUST86849            Cereal        242.40
# 1004999  ORD0121959   CUST61990        Makeup Kit       5597.55
#
#            payment_method       city order_status
# 0        Cash On Delivery       Pune    Delivered
# 1              Debit Card    Kolkata    Delivered
# ...

# %% [markdown]
# ### TASK 5.3: Use loc and iloc

# %%
Ecom_df.head(2)
# Out:
#      order_id customer_id          order_date       delivery_date  \
# 0  ORD0499319   CUST81768 2024-11-06 19:04:00 2024-11-14 19:04:00
# 1  ORD0380643   CUST30450 2024-09-09 22:22:00 2024-09-15 22:22:00
#
#      product_name        category  quantity    price  total_amount  \
# 0        Vacuum    Home & Kitchen         4  2191.51       8766.04
# 1  Organic Snacks         Grocery         3   704.72       2114.16
#
#      payment_method     city order_status  order_year  order_month  order_day  \
# 0  Cash On Delivery     Pune    Delivered        2024           11          6
# 1        Debit Card  Kolkata    Delivered        2024            9          9
#
#   order_weekday  delivery_days price_category customer_segment  \
# 0     Wednesday              8            Low           Bronze
# 1        Monday              6            Low           Bronze
#
#    product_revenue_percent
# 0                 0.032350
# 1                 0.006086

# %%
#filtering 4 row and 2 columns using iloc
Ecom_df.iloc[0:4,0:2]
# Out:
#      order_id customer_id
# 0  ORD0499319   CUST81768
# 1  ORD0380643   CUST30450
# 2  ORD0371106   CUST82803
# 3  ORD0150743   CUST82106

# %%
# filtering first 5 rows 
Ecom_df.loc[0:4,'customer_id':'product_name']
# Out:
#   customer_id          order_date       delivery_date      product_name
# 0   CUST81768 2024-11-06 19:04:00 2024-11-14 19:04:00          Vacuum
# 1   CUST30450 2024-09-09 22:22:00 2024-09-15 22:22:00    Organic Snacks
# 2   CUST82803 2024-08-23 07:22:00 2024-08-31 07:22:00          Lego Set
# 3   CUST82106 2024-07-03 19:52:00 2024-07-13 19:52:00    Coffee Maker
# 4   CUST71248 2024-02-11 11:19:00 2024-02-18 11:19:00             Dress

# %%
Ecom_df.loc[0:4,:]
# Out:
#      order_id customer_id          order_date       delivery_date  \
# 0  ORD0499319   CUST81768 2024-11-06 19:04:00 2024-11-14 19:04:00
# 1  ORD0380643   CUST30450 2024-09-09 22:22:00 2024-09-15 22:22:00
# 2  ORD0371106   CUST82803 2024-08-23 07:22:00 2024-08-31 07:22:00
# 3  ORD0150743   CUST82106 2024-07-03 19:52:00 2024-07-13 19:52:00
# 4  ORD0619524   CUST71248 2024-02-11 11:19:00 2024-02-18 11:19:00
#
#        product_name        category  quantity    price  total_amount  \
# 0          Vacuum    Home & Kitchen         4  2191.51       8766.04
# 1    Organic Snacks         Grocery         3   704.72       2114.16
# 2          Lego Set            Toys         2   694.01       1388.02
# 3    Coffee Maker    Home & Kitchen         4  7376.81      29507.24
# 4             Dress        Clothing         4  2774.72      11098.88
#
#      payment_method       city order_status  order_year  order_month  \
# 0  Cash On Delivery       Pune    Delivered        2024           11
# ...

# %%
Ecom_df.iloc[0:4,:]
# Out:
#      order_id customer_id          order_date       delivery_date  \
# 0  ORD0499319   CUST81768 2024-11-06 19:04:00 2024-11-14 19:04:00
# 1  ORD0380643   CUST30450 2024-09-09 22:22:00 2024-09-15 22:22:00
# 2  ORD0371106   CUST82803 2024-08-23 07:22:00 2024-08-31 07:22:00
# 3  ORD0150743   CUST82106 2024-07-03 19:52:00 2024-07-13 19:52:00
#
#        product_name        category  quantity    price  total_amount  \
# 0          Vacuum    Home & Kitchen         4  2191.51       8766.04
# 1    Organic Snacks         Grocery         3   704.72       2114.16
# 2          Lego Set            Toys         2   694.01       1388.02
# 3    Coffee Maker    Home & Kitchen         4  7376.81      29507.24
#
#      payment_method       city order_status  order_year  order_month  \
# 0  Cash On Delivery       Pune    Delivered        2024           11
# 1        Debit Card    Kolkata    Delivered        2024            9
# 2  Cash On Delivery  Bangalore    Delivered        2024            8
# ...

# %% [markdown]
#  ### TASK 5.4: Query Method

# %%
#Filter data using the query() function for readability
Ecom_df.query("(price<5000) &( city=='Kolkata')")
# Out:
#            order_id customer_id          order_date       delivery_date  \
# 1        ORD0380643   CUST30450 2024-09-09 22:22:00 2024-09-15 22:22:00
# 65       ORD0210271   CUST47281 2023-01-08 22:29:00 2023-01-12 22:29:00
# 72       ORD0252871   CUST55918 2023-12-25 13:53:00 2024-01-01 13:53:00
# 75       ORD0534761   CUST32155 2024-12-10 20:15:00 2024-12-17 20:15:00
# 78       ORD0734837   CUST26741 2024-11-08 17:48:00 2024-11-12 17:48:00
# ...             ...         ...                 ...                 ...
# 1004934  ORD0349458   CUST29438 2024-03-16 15:56:00 2024-03-21 15:56:00
# 1004939  ORD0528179   CUST45761 2024-10-19 07:51:00 2024-10-23 07:51:00
# 1004969  ORD0235797   CUST69504 2023-06-12 10:48:00 2023-06-18 10:48:00
# 1004972  ORD0199042   CUST81308 2023-03-20 01:39:00 2023-03-23 01:39:00
# 1004998  ORD0671156   CUST86849 2024-09-22 02:03:00 2024-09-30 02:03:00
#
#            product_name  category  quantity    price  total_amount  \
# ...

# %%
Ecom_df.query("(category=='Grocery') & (payment_method=='Debit Card')")
# Out:
#            order_id customer_id          order_date       delivery_date  \
# 1        ORD0380643   CUST30450 2024-09-09 22:22:00 2024-09-15 22:22:00
# 84       ORD0263898   CUST36764 2023-11-17 11:13:00 2023-11-26 11:13:00
# 141      ORD0898257   CUST29795 2023-06-19 05:38:00 2023-06-25 05:38:00
# 144      ORD0453611   CUST89373 2024-09-17 00:06:00 2024-09-20 00:06:00
# 147      ORD0146495   CUST36320 2024-11-09 09:29:00 2024-11-17 09:29:00
# ...             ...         ...                 ...                 ...
# 1004853  ORD0129313   CUST53904 2023-11-24 06:10:00 2023-11-27 06:10:00
# 1004863  ORD0985068   CUST57866 2023-12-19 07:12:00 2023-12-25 07:12:00
# 1004871  ORD0837647   CUST83408 2023-12-05 00:59:00 2023-12-08 00:59:00
# 1004875  ORD0926076   CUST29841 2023-09-19 18:37:00 2023-09-26 18:37:00
# 1004893  ORD0535823   CUST39523 2023-06-09 17:51:00 2023-06-17 17:51:00
#
#            product_name category  quantity   price  total_amount  \
# ...

# %%
Ecom_df.query("(product_name=='Cereal' | city=='Delhi') & (order_status=='Returned')")
# Out:
#            order_id customer_id          order_date       delivery_date  \
# 32       ORD0736800   CUST92663 2023-09-06 06:42:00 2023-09-15 06:42:00
# 82       ORD0921713   CUST36505 2023-06-12 08:04:00 2023-06-20 08:04:00
# 208      ORD0896245   CUST65476 2023-12-13 04:33:00 2023-12-18 04:33:00
# 219      ORD0960246   CUST43587 2023-11-20 22:31:00 2023-11-24 22:31:00
# 244      ORD0884905   CUST79657 2023-11-09 08:08:00 2023-11-18 08:08:00
# ...             ...         ...                 ...                 ...
# 1004784  ORD0379990   CUST98891 2023-05-31 23:53:00 2023-06-09 23:53:00
# 1004823  ORD0472526   CUST37890 2024-05-23 08:38:00 2024-05-29 08:38:00
# 1004871  ORD0837647   CUST83408 2023-12-05 00:59:00 2023-12-08 00:59:00
# 1004916  ORD0803592   CUST53199 2023-02-26 17:46:00 2023-03-05 17:46:00
# 1004924  ORD0777090   CUST23337 2024-02-03 17:43:00 2024-02-12 17:43:00
#
#         product_name category  quantity    price  total_amount  \
# ...

# %% [markdown]
# ## PART 6: GROUPING & AGGREGATION

# %% [markdown]
# ### TASK 6.1: Basic Aggregations

# %%
Ecom_df.head(2)
# Out:
#      order_id customer_id          order_date       delivery_date  \
# 0  ORD0499319   CUST81768 2024-11-06 19:04:00 2024-11-14 19:04:00
# 1  ORD0380643   CUST30450 2024-09-09 22:22:00 2024-09-15 22:22:00
#
#      product_name        category  quantity    price  total_amount  \
# 0        Vacuum    Home & Kitchen         4  2191.51       8766.04
# 1  Organic Snacks         Grocery         3   704.72       2114.16
#
#      payment_method     city order_status  order_year  order_month  order_day  \
# 0  Cash On Delivery     Pune    Delivered        2024           11          6
# 1        Debit Card  Kolkata    Delivered        2024            9          9
#
#   order_weekday  delivery_days price_category customer_segment  \
# 0     Wednesday              8            Low           Bronze
# 1        Monday              6            Low           Bronze
#
#    product_revenue_percent
# 0                 0.032350
# 1                 0.006086

# %%
Ecom_df['price'].mean()
# Out:
# np.float64(7270.527994864219)

# %%
Ecom_df['total_amount'].sum()
# Out:
# np.float64(19702461929.72)

# %%
#making sure there are no negative values in quantity column 
Ecom_df['quantity']=Ecom_df['quantity'].abs()

# %%
Ecom_df['quantity'].min()
# Out:
# np.int64(1)

# %%
Ecom_df['delivery_days'].dtype
# Out:
# dtype('int64')

# %%
#converting to numeric datatype and fill the misising values with zero
Ecom_df['delivery_days']=pd.to_numeric(Ecom_df['delivery_days'],errors='coerce')
Ecom_df['delivery_days'] = pd.to_numeric(Ecom_df['delivery_days'], errors='coerce').fillna(0).astype(int)
Ecom_df['delivery_days']=Ecom_df['delivery_days'].abs()

# %%
#chhecking for the  data type
Ecom_df['delivery_days'].dtype
# Out:
# dtype('int64')

# %%
Ecom_df['delivery_days'].max()
# Out:
# np.int64(28)

# %% [markdown]
# ### TASK 6.2: Group by Single Column

# %%
Ecom_df.head(2)
# Out:
#      order_id customer_id          order_date       delivery_date  \
# 0  ORD0499319   CUST81768 2024-11-06 19:04:00 2024-11-14 19:04:00
# 1  ORD0380643   CUST30450 2024-09-09 22:22:00 2024-09-15 22:22:00
#
#      product_name        category  quantity    price  total_amount  \
# 0        Vacuum    Home & Kitchen         4  2191.51       8766.04
# 1  Organic Snacks         Grocery         3   704.72       2114.16
#
#      payment_method     city order_status  order_year  order_month  order_day  \
# 0  Cash On Delivery     Pune    Delivered        2024           11          6
# 1        Debit Card  Kolkata    Delivered        2024            9          9
#
#   order_weekday  delivery_days price_category customer_segment  \
# 0     Wednesday              8            Low           Bronze
# 1        Monday              6            Low           Bronze
#
#    product_revenue_percent
# 0                 0.032350
# 1                 0.006086

# %%
#Group data by one column (e.g., category) and aggregate totals
#all rows with the same category are grouped together
Ecom_df.groupby('category')['total_amount'].sum().round(2)
# Out:
# category
# Beauty            3.858681e+08
# Books             1.679326e+08
# Clothing          5.537746e+08
# Electronics       1.437483e+10
# Grocery           1.836694e+08
# Home & Kitchen    2.666882e+09
# Sports            9.198924e+08
# Toys              4.496075e+08
# Name: total_amount, dtype: float64

# %%
Ecom_df['total_amount'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### TASK 6.3: Group by Multiple Columns

# %%
Ecom_df.groupby(['city','payment_method'],as_index=False)['total_amount'].sum().round(2)
# index false will give a dataframe
# Out:
#          city    payment_method  total_amount
# 0   Ahmedabad  Cash On Delivery  3.950488e+08
# 1   Ahmedabad       Credit Card  3.867099e+08
# 2   Ahmedabad        Debit Card  3.960790e+08
# 3   Ahmedabad       Net Banking  3.911738e+08
# 4   Ahmedabad               Upi  3.946321e+08
# 5   Bangalore  Cash On Delivery  3.877244e+08
# 6   Bangalore       Credit Card  3.904961e+08
# 7   Bangalore        Debit Card  3.899291e+08
# 8   Bangalore       Net Banking  3.881940e+08
# 9   Bangalore               Upi  3.946103e+08
# 10    Chennai  Cash On Delivery  3.868031e+08
# 11    Chennai       Credit Card  3.899348e+08
# 12    Chennai        Debit Card  3.978456e+08
# 13    Chennai       Net Banking  3.988761e+08
# 14    Chennai               Upi  3.991644e+08
# 15      Delhi  Cash On Delivery  3.930898e+08
# 16      Delhi       Credit Card  3.809473e+08
# 17      Delhi        Debit Card  3.821070e+08
# 18      Delhi       Net Banking  3.956603e+08
# ...

# %% [markdown]
# ### TASK 6.4: Multiple Aggregations

# %%
Ecom_df.groupby(['city','order_status'])['total_amount'].agg(['sum','mean','max']).round(2)
# Out:
#                                  sum      mean        max
# city      order_status
# Ahmedabad Delivered     1.348764e+09  21623.48  399700.25
#           Pending       1.613802e+08  22049.49  389227.20
#           Returned      4.534990e+08  22041.26  399830.25
# Bangalore Delivered     1.353513e+09  21753.67  399694.45
#           Pending       1.537779e+08  21640.57  398167.15
#           Returned      4.436626e+08  21517.18  399981.95
# Chennai   Delivered     1.355780e+09  21676.87  399977.65
#           Pending       1.559880e+08  22236.35  397139.55
#           Returned      4.608564e+08  22341.30  399997.95
# Delhi     Delivered     1.347102e+09  21649.23  399918.65
#           Pending       1.598613e+08  22040.72  398757.80
#           Returned      4.435464e+08  21469.89  399067.95
# Hyderabad Delivered     1.373720e+09  22071.34  399513.35
#           Pending       1.614951e+08  22146.88  398662.00
#           Returned      4.667660e+08  22439.59  398190.80
# ...

# %%
Ecom_df.groupby(['category','payment_method'])['total_amount'].agg(['mean','max']).round(2)
# Out:
#                                       mean        max
# category       payment_method
# Beauty         Cash On Delivery    3418.69    9997.55
#                Credit Card         3415.14    9998.65
#                Debit Card          3402.83    9997.90
#                Net Banking         3407.46    9998.90
#                Upi                 3432.81    9999.60
# Books          Cash On Delivery    1496.58    3999.90
#                Credit Card         1483.87    3999.35
#                Debit Card          1489.47    3999.60
#                Net Banking         1488.50    3999.70
#                Upi                 1488.23    3999.45
# Clothing       Cash On Delivery    4897.96   14992.65
#                Credit Card         4906.89   14993.55
#                Debit Card          4886.12   14998.70
#                Net Banking         4909.60   14999.25
#                Upi                 4897.11   14997.95
# Electronics    Cash On Delivery  125713.42  399997.95
# ...

# %% [markdown]
# ### TASK 6.5: Advanced Aggregations

# %%
#Use advanced group operations like apply() or transform()
Ecom_df.head(2)
# Out:
#      order_id customer_id          order_date       delivery_date  \
# 0  ORD0499319   CUST81768 2024-11-06 19:04:00 2024-11-14 19:04:00
# 1  ORD0380643   CUST30450 2024-09-09 22:22:00 2024-09-15 22:22:00
#
#      product_name        category  quantity    price  total_amount  \
# 0        Vacuum    Home & Kitchen         4  2191.51       8766.04
# 1  Organic Snacks         Grocery         3   704.72       2114.16
#
#      payment_method     city order_status  order_year  order_month  order_day  \
# 0  Cash On Delivery     Pune    Delivered        2024           11          6
# 1        Debit Card  Kolkata    Delivered        2024            9          9
#
#   order_weekday  delivery_days price_category customer_segment  \
# 0     Wednesday              8            Low           Bronze
# 1        Monday              6            Low           Bronze
#
#    product_revenue_percent
# 0                 0.032350
# 1                 0.006086

# %%
Ecom_df['product_revenue_percent'] = Ecom_df.groupby('product_name')['total_amount'].transform(lambda x: (x / x.sum()) * 100)
Ecom_df[['product_name', 'total_amount', 'product_revenue_percent']]
# Out:
#              product_name  total_amount  product_revenue_percent
# 0                Vacuum         8766.04                 0.032350
# 1          Organic Snacks       2114.16                 0.006086
# 2                Lego Set       1388.02                 0.001644
# 3          Coffee Maker        29507.24                 0.113392
# 4                   Dress      11098.88                 0.012805
# ...                   ...           ...                      ...
# 1004995      Cookware Set      57744.20                 0.011286
# 1004996          Cookbook       1890.42                 0.005896
# 1004997        Board Game       2383.59                 0.002792
# 1004998            Cereal        242.40                 0.000693
# 1004999        Makeup Kit       5597.55                 0.007615
#
# [903076 rows x 3 columns]

# %% [markdown]
# ## PART 7: SORTING & RANKING

# %% [markdown]
# ### TASK 7.1: Sort Data

# %%
#Sort by one or multiple columns
Ecom_df.sort_index()
    #.sort_values(by=['order_id','order_date'])
# Out:
#            order_id customer_id          order_date       delivery_date  \
# 0        ORD0499319   CUST81768 2024-11-06 19:04:00 2024-11-14 19:04:00
# 1        ORD0380643   CUST30450 2024-09-09 22:22:00 2024-09-15 22:22:00
# 2        ORD0371106   CUST82803 2024-08-23 07:22:00 2024-08-31 07:22:00
# 3        ORD0150743   CUST82106 2024-07-03 19:52:00 2024-07-13 19:52:00
# 4        ORD0619524   CUST71248 2024-02-11 11:19:00 2024-02-18 11:19:00
# ...             ...         ...                 ...                 ...
# 1004995  ORD0259179   CUST55662 2024-12-01 02:05:00 2024-12-10 02:05:00
# 1004996  ORD0365839   CUST87001 2024-09-16 21:13:00 2024-09-24 21:13:00
# 1004997  ORD0131933   CUST10790 2023-06-24 17:09:00 2023-07-03 17:09:00
# 1004998  ORD0671156   CUST86849 2024-09-22 02:03:00 2024-09-30 02:03:00
# 1004999  ORD0121959   CUST61990 2023-09-16 21:59:00 2023-09-25 21:59:00
#
#              product_name        category  quantity     price  total_amount  \
# ...

# %%
#Sort by one or multiple columns
Ecom_df.sort_values(by=['order_id','order_date'],ascending=[True,False])
# Out:
#           order_id customer_id          order_date       delivery_date  \
# 48631   ORD0000001   CUST23434 2023-02-16 06:53:00 2024-01-07 02:55:00
# 794471  ORD0000002   CUST10851 2024-02-09 16:18:00 2024-02-17 16:18:00
# 406307  ORD0000003   CUST59615 2024-06-10 16:03:00 2024-06-14 16:03:00
# 862680  ORD0000004   CUST57819 2023-04-14 23:41:00 2023-04-19 23:41:00
# 632143  ORD0000005   CUST14207 2024-04-03 06:47:00 2024-04-13 06:47:00
# ...            ...         ...                 ...                 ...
# 396146  ORD0999995   CUST66535 2023-07-08 23:28:00 2023-07-15 23:28:00
# 328453  ORD0999996   CUST68443 2024-05-04 11:28:00 2024-05-07 11:28:00
# 76144   ORD0999997   CUST13456 2023-04-03 16:56:00 2023-04-06 16:56:00
# 465321  ORD0999999   CUST80146 2024-06-01 19:19:00 2024-06-06 19:19:00
# 575120  ORD1000000   CUST37261 2024-08-26 08:55:00 2024-09-01 08:55:00
#
#          product_name        category  quantity     price  total_amount  \
# ...

# %% [markdown]
# ### TASK 7.2: Find Top and Bottom Records

# %%
#Use nlargest() and nsmallest()
#DataFrame.nlargest(n, columns, keep='first')

# %% [markdown]
# + DataFrame.nlargest(n, columns, keep='first')
# + n: int, Number of values to select
# + columns: Column to check for values or user can select column while calling too.
# + example: data["age"].nsmallest(3) OR data.nsmallest(3, "age")]
# + keep: object to set which value to select if duplicates exit. Options are 'first' or 'last'

# %%
#Which are the top-selling and least-selling products?
Ecom_df.head(2)
# Out:
#      order_id customer_id          order_date       delivery_date  \
# 0  ORD0499319   CUST81768 2024-11-06 19:04:00 2024-11-14 19:04:00
# 1  ORD0380643   CUST30450 2024-09-09 22:22:00 2024-09-15 22:22:00
#
#      product_name        category  quantity    price  total_amount  \
# 0        Vacuum    Home & Kitchen         4  2191.51       8766.04
# 1  Organic Snacks         Grocery         3   704.72       2114.16
#
#      payment_method     city order_status  order_year  order_month  order_day  \
# 0  Cash On Delivery     Pune    Delivered        2024           11          6
# 1        Debit Card  Kolkata    Delivered        2024            9          9
#
#   order_weekday  delivery_days price_category customer_segment  \
# 0     Wednesday              8            Low           Bronze
# 1        Monday              6            Low           Bronze
#
#    product_revenue_percent
# 0                 0.032350
# 1                 0.006086

# %%
Ecom_df.groupby('product_name')['total_amount'].sum()
# here product_name is index
# Out:
# product_name
#   Action Figure      4.553518e+06
#   Bicycle            9.327538e+06
#   Biography          1.655637e+06
#   Blender            2.719152e+07
#   Board Game         4.541815e+06
#                          ...
# T-Shirt              8.801135e+07
# Tablet               2.284532e+09
# Tennis Racket        1.770557e+08
# Vacuum               5.047144e+08
# Yoga Mat             1.760596e+08
# Name: total_amount, Length: 84, dtype: float64

# %%
Ecom_df.groupby('product_name')['total_amount'].sum().round(2).reset_index()
# using reset_index product_name is included under column not index
# Out:
#          product_name  total_amount
# 0     Action Figure    4.553518e+06
# 1           Bicycle    9.327538e+06
# 2         Biography    1.655637e+06
# 3           Blender    2.719152e+07
# 4        Board Game    4.541815e+06
# ..                ...           ...
# 79            T-Shirt  8.801135e+07
# 80             Tablet  2.284532e+09
# 81      Tennis Racket  1.770557e+08
# 82             Vacuum  5.047144e+08
# 83           Yoga Mat  1.760596e+08
#
# [84 rows x 2 columns]

# %%
#top most sold
Ecom_df.groupby('product_name')['total_amount'].sum().reset_index().nlargest(5,'total_amount')
# Out:
#    product_name  total_amount
# 76   Smartphone  2.296014e+09
# 47       Camera  2.286893e+09
# 80       Tablet  2.284532e+09
# 61       Laptop  2.272548e+09
# 58   Headphones  2.268110e+09

# %%
#least sold
Ecom_df.groupby('product_name')['total_amount'].sum().reset_index().nsmallest(5,'total_amount')
# Out:
#          product_name  total_amount
# 9          Cookbook      1625742.50
# 31        Self-Help      1642223.69
# 30     Science Book      1646804.48
# 15    Fiction Novel      1655342.08
# 2         Biography      1655637.06

# %% [markdown]
# ## PART 8: BUSINESS QUESTIONS

# %% [markdown]
# + <b> Which Category Generates the Most Revenue?</b>

# %%
Ecom_df.head()
# Out:
#      order_id customer_id          order_date       delivery_date  \
# 0  ORD0499319   CUST81768 2024-11-06 19:04:00 2024-11-14 19:04:00
# 1  ORD0380643   CUST30450 2024-09-09 22:22:00 2024-09-15 22:22:00
# 2  ORD0371106   CUST82803 2024-08-23 07:22:00 2024-08-31 07:22:00
# 3  ORD0150743   CUST82106 2024-07-03 19:52:00 2024-07-13 19:52:00
# 4  ORD0619524   CUST71248 2024-02-11 11:19:00 2024-02-18 11:19:00
#
#        product_name        category  quantity    price  total_amount  \
# 0          Vacuum    Home & Kitchen         4  2191.51       8766.04
# 1    Organic Snacks         Grocery         3   704.72       2114.16
# 2          Lego Set            Toys         2   694.01       1388.02
# 3    Coffee Maker    Home & Kitchen         4  7376.81      29507.24
# 4             Dress        Clothing         4  2774.72      11098.88
#
#      payment_method       city order_status  order_year  order_month  \
# 0  Cash On Delivery       Pune    Delivered        2024           11
# ...

# %%
Ecom_df.groupby('category')['total_amount'].sum().round(2).nlargest(5)
#Electronics category generates the highest revenue
# Out:
# category
# Electronics       1.437483e+10
# Home & Kitchen    2.666882e+09
# Sports            9.198924e+08
# Clothing          5.537746e+08
# Toys              4.496075e+08
# Name: total_amount, dtype: float64

# %% [markdown]
# + <b>Month-over-Month Revenue Trend</b>

# %%
Monthly_revenue=Ecom_df.groupby('order_month')['total_amount'].sum().reset_index().round(2)
print(Monthly_revenue)
# Out:
#     order_month  total_amount
# 0             1  1.668119e+09
# 1             2  1.544301e+09
# 2             3  1.673868e+09
# 3             4  1.613200e+09
# 4             5  1.655029e+09
# 5             6  1.636346e+09
# 6             7  1.684286e+09
# 7             8  1.661956e+09
# 8             9  1.604132e+09
# 9            10  1.666757e+09
# 10           11  1.622668e+09
# 11           12  1.671802e+09

# %%
import matplotlib.pyplot as plt

plt.bar(Monthly_revenue['order_month'],Monthly_revenue['total_amount'],
    color=['lightgreen', 'lightblue', 'orange'],edgecolor='black' 
)
plt.title('Month over Month Revenue Trend\n',fontsize=12,fontweight='bold')
plt.xlabel('Order Month\n',fontsize=10)
plt.ylabel('Total Amount\n',fontsize=10)
plt.show()

# %% [markdown]
# +  <b>City with the Highest Number of Customers</b>

# %%
Ecom_df.groupby('city')['customer_id'].nunique().nlargest(1)
#surat has high no.of customers
# Out:
# city
# Surat    57275
# Name: customer_id, dtype: int64

# %% [markdown]
# +  <b>Average Delivery Time by Category</b>

# %%
Ecom_df.groupby('category')['delivery_days'].mean().round(2).reset_index()
# Out:
#          category  delivery_days
# 0          Beauty           9.04
# 1           Books           9.06
# 2        Clothing           9.06
# 3     Electronics           9.05
# 4         Grocery           9.04
# 5  Home & Kitchen           9.04
# 6          Sports           9.07
# 7            Toys           9.05

# %% [markdown]
# + <b>Most Popular Payment Method</b>

# %%
Ecom_df['payment_method'].value_counts().head(1)
#Debit card is most popular
# Out:
# payment_method
# Debit Card    180837
# Name: count, dtype: int64

# %% [markdown]
# + <b>Top Products per Category</b>

# %%
Ecom_df.groupby(['category','product_name'])['total_amount'].sum().reset_index().nlargest(5,'total_amount')
# Out:
#        category product_name  total_amount
# 41  Electronics   Smartphone  2.296014e+09
# 38  Electronics       Camera  2.286893e+09
# 43  Electronics       Tablet  2.284532e+09
# 40  Electronics       Laptop  2.272548e+09
# 39  Electronics   Headphones  2.268110e+09

# %% [markdown]
# + <b>Day of Week with Most Orders</b>

# %%
Ecom_df.head(2)
# Out:
#      order_id customer_id          order_date       delivery_date  \
# 0  ORD0499319   CUST81768 2024-11-06 19:04:00 2024-11-14 19:04:00
# 1  ORD0380643   CUST30450 2024-09-09 22:22:00 2024-09-15 22:22:00
#
#      product_name        category  quantity    price  total_amount  \
# 0        Vacuum    Home & Kitchen         4  2191.51       8766.04
# 1  Organic Snacks         Grocery         3   704.72       2114.16
#
#      payment_method     city order_status  order_year  order_month  order_day  \
# 0  Cash On Delivery     Pune    Delivered        2024           11          6
# 1        Debit Card  Kolkata    Delivered        2024            9          9
#
#   order_weekday  delivery_days price_category customer_segment  \
# 0     Wednesday              8            Low           Bronze
# 1        Monday              6            Low           Bronze
#
#    product_revenue_percent
# 0                 0.032350
# 1                 0.006086

# %%
Ecom_df['order_weekday'].value_counts().head(1)
#Monday has more no.of orders
# Out:
# order_weekday
# Monday    130174
# Name: count, dtype: int64

# %% [markdown]
# + <b>Return Rate by Category</b>

# %%
Ecom_df['category']
# Out:
# 0          Home & Kitchen
# 1                 Grocery
# 2                    Toys
# 3          Home & Kitchen
# 4                Clothing
#                 ...
# 1004995    Home & Kitchen
# 1004996             Books
# 1004997              Toys
# 1004998           Grocery
# 1004999            Beauty
# Name: category, Length: 903076, dtype: object

# %%
return_rate = (Ecom_df.groupby('category')['order_status']
    .apply(lambda x: (x == 'Returned').sum() / len(x) * 100)
    .reset_index(name='return_rate (%)')
)

print(return_rate)
# Out:
#          category  return_rate (%)
# 0          Beauty        22.976633
# 1           Books        22.897913
# 2        Clothing        22.966194
# 3     Electronics        22.945956
# 4         Grocery        22.958827
# 5  Home & Kitchen        22.868162
# 6          Sports        22.932637
# 7            Toys        23.173449

# %% [markdown]
# + <b>Distribution of Customer Segments</b>

# %%
Ecom_df['customer_segment'].value_counts()
# Out:
# customer_segment
# Bronze    845372
# Silver     43456
# Gold       14248
# Name: count, dtype: int64

# %%
help(plt.bar)
# Out:
# Help on function bar in module matplotlib.pyplot:
#
# bar(x: 'float | ArrayLike', height: 'float | ArrayLike', width: 'float | ArrayLike' = 0.8, bottom: 'float | ArrayLike | None' = None, *, align: "Literal['center', 'edge']" = 'center', data=None, **kwargs) -> 'BarContainer'
#     Make a bar plot.
#
#     The bars are positioned at *x* with the given *align*\ment. Their
#     dimensions are given by *height* and *width*. The vertical baseline
#     is *bottom* (default 0).
#
#     Many parameters can take either a single value applying to all bars
#     or a sequence of values, one for each bar.
#
#     Parameters
#     ----------
#     x : float or array-like
#         The x coordinates of the bars. See also *align* for the
#         alignment of the bars to the coordinates.
#
#         Bars are often used for categorical data, i.e. string labels below
#         the bars. You can provide a list of strings directly to *x*.
# ...

# %%
import matplotlib.pyplot as plt

Ecom_df['customer_segment'].value_counts().plot(
    kind='bar',
    color=['green', 'red', 'blue'],edgecolor='black'  # bronze, silver, gold colors
)
plt.title('Customer Segment Distribution\n',fontsize=12,fontweight='bold')
plt.xlabel('Customer Segment\n',fontsize=10)
plt.ylabel('Number of Customers\n',fontsize=10)
plt.show()

# %% [markdown]
# ## PART 9: DATA EXPORT

# %%
#Export the final cleaned DataFrame as ecommerce_cleaned.csv
Ecom_df.to_csv('ecommerce_cleaned.csv', index=False)
#to_csv() → writes your DataFrame to a CSV file
#index=False → prevents pandas from adding the DataFrame index as an extra column

# %% [markdown]
# ## PART 10: BONUS CHALLENGES

# %% [markdown]
# + <b>Pivot Table – Create summary tables by category/month</b>

# %%
Ecom_df.head(2)
# Out:
#      order_id customer_id          order_date       delivery_date  \
# 0  ORD0499319   CUST81768 2024-11-06 19:04:00 2024-11-14 19:04:00
# 1  ORD0380643   CUST30450 2024-09-09 22:22:00 2024-09-15 22:22:00
#
#      product_name        category  quantity    price  total_amount  \
# 0        Vacuum    Home & Kitchen         4  2191.51       8766.04
# 1  Organic Snacks         Grocery         3   704.72       2114.16
#
#      payment_method     city order_status  order_year  order_month  order_day  \
# 0  Cash On Delivery     Pune    Delivered        2024           11          6
# 1        Debit Card  Kolkata    Delivered        2024            9          9
#
#   order_weekday  delivery_days price_category customer_segment  \
# 0     Wednesday              8            Low           Bronze
# 1        Monday              6            Low           Bronze
#
#    product_revenue_percent
# 0                 0.032350
# 1                 0.006086

# %%
pivot=Ecom_df.pivot_table(index=['category'],values=['total_amount'],aggfunc='mean')
print(pivot)
# Out:
#                  total_amount
# category
# Beauty            3415.366023
# Books             1489.332065
# Clothing          4899.489249
# Electronics     126546.837760
# Grocery           1625.235101
# Home & Kitchen   23698.880604
# Sports            8142.802079
# Toys              4006.982878

# %%
pivot=Ecom_df.pivot_table(index=['order_month'],values=['total_amount'],aggfunc='mean')
print(pivot)
# Out:
#              total_amount
# order_month
# 1            21683.308733
# 2            21985.749807
# 3            21834.960553
# 4            21749.452545
# 5            21703.871596
# 6            21995.672076
# 7            21916.247643
# 8            21610.220613
# 9            21563.516494
# 10           21813.617670
# 11           21917.277357
# 12           22046.710243

# %% [markdown]
# + <b>Repeat Customers – Identify customers with multiple orders</b>

# %%
Ecom_df[Ecom_df['customer_id'].duplicated(keep=False)]
# Out:
#            order_id customer_id          order_date       delivery_date  \
# 0        ORD0499319   CUST81768 2024-11-06 19:04:00 2024-11-14 19:04:00
# 1        ORD0380643   CUST30450 2024-09-09 22:22:00 2024-09-15 22:22:00
# 2        ORD0371106   CUST82803 2024-08-23 07:22:00 2024-08-31 07:22:00
# 3        ORD0150743   CUST82106 2024-07-03 19:52:00 2024-07-13 19:52:00
# 4        ORD0619524   CUST71248 2024-02-11 11:19:00 2024-02-18 11:19:00
# ...             ...         ...                 ...                 ...
# 1004995  ORD0259179   CUST55662 2024-12-01 02:05:00 2024-12-10 02:05:00
# 1004996  ORD0365839   CUST87001 2024-09-16 21:13:00 2024-09-24 21:13:00
# 1004997  ORD0131933   CUST10790 2023-06-24 17:09:00 2023-07-03 17:09:00
# 1004998  ORD0671156   CUST86849 2024-09-22 02:03:00 2024-09-30 02:03:00
# 1004999  ORD0121959   CUST61990 2023-09-16 21:59:00 2023-09-25 21:59:00
#
#              product_name        category  quantity     price  total_amount  \
# ...

# %% [markdown]
# + <b>Seasonal Analysis – Detect seasonal sales patterns</b>

# %%
Ecom_df.head(2)
# Out:
#      order_id customer_id          order_date       delivery_date  \
# 0  ORD0499319   CUST81768 2024-11-06 19:04:00 2024-11-14 19:04:00
# 1  ORD0380643   CUST30450 2024-09-09 22:22:00 2024-09-15 22:22:00
#
#      product_name        category  quantity    price  total_amount  \
# 0        Vacuum    Home & Kitchen         4  2191.51       8766.04
# 1  Organic Snacks         Grocery         3   704.72       2114.16
#
#      payment_method     city order_status  order_year  order_month  order_day  \
# 0  Cash On Delivery     Pune    Delivered        2024           11          6
# 1        Debit Card  Kolkata    Delivered        2024            9          9
#
#   order_weekday  delivery_days price_category customer_segment  \
# 0     Wednesday              8            Low           Bronze
# 1        Monday              6            Low           Bronze
#
#    product_revenue_percent
# 0                 0.032350
# 1                 0.006086

# %%
monthly_sales=Ecom_df.groupby('order_month')['total_amount'].sum().reset_index()
print(monthly_sales)
# Out:
#     order_month  total_amount
# 0             1  1.668119e+09
# 1             2  1.544301e+09
# 2             3  1.673868e+09
# 3             4  1.613200e+09
# 4             5  1.655029e+09
# 5             6  1.636346e+09
# 6             7  1.684286e+09
# 7             8  1.661956e+09
# 8             9  1.604132e+09
# 9            10  1.666757e+09
# 10           11  1.622668e+09
# 11           12  1.671802e+09

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args: 'float | ArrayLike | str', scalex: 'bool' = True, scaley: 'bool' = True, data=None, **kwargs) -> 'list[Line2D]'
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
#visualizing the monthly sales
import matplotlib.pyplot as plt

plt.plot(monthly_sales['order_month'],monthly_sales['total_amount'],linestyle='--',color='m',marker='p')
plt.title('Seasonal Monthly Wise Sales\n',fontsize=12,fontweight='bold')
plt.xlabel('order Month\n',fontsize=10)
plt.ylabel('Total Amount\n',fontsize=10)

plt.show()

# %%
#Yearly sales
Ecom_df.columns
# Out:
# Index(['order_id', 'customer_id', 'order_date', 'delivery_date',
#        'product_name', 'category', 'quantity', 'price', 'total_amount',
#        'payment_method', 'city', 'order_status', 'order_year', 'order_month',
#        'order_day', 'order_weekday', 'delivery_days', 'price_category',
#        'customer_segment', 'product_revenue_percent'],
#       dtype='object')

# %%
Yearly_sales=Ecom_df.groupby('order_year')['total_amount'].sum().reset_index()
print(Yearly_sales)
# Out:
#    order_year  total_amount
# 0        2023  9.854401e+09
# 1        2024  9.848061e+09

# %%
#visualizing the yearly sales
import matplotlib.pyplot as plt

plt.plot(Yearly_sales['order_year'],Yearly_sales['total_amount'],linestyle='-',color='c',marker='2')
plt.title('Seasonal Yearly Wise Sales\n',fontsize=12,fontweight='bold')
plt.xlabel('order Year\n',fontsize=10)
plt.ylabel('Total Amount\n',fontsize=10)

plt.show()
